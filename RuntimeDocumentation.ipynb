# %%
from rich import inspect, pretty
from rich import print
from rich.traceback import install

install(show_locals=True)
pretty.install()

# %%
# Out:
# {
#     '__name__': '__main__',
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__package__': None,
#     '__loader__': None,
#     '__spec__': None,
#     '__builtin__': <module 'builtins' (built-in)>,
#     '__builtins__': <module 'builtins' (built-in)>,
#     '_ih': [
#         '',
#         'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#         'locals()',
#         'vars()'
#     ],
#     '_oh': {10: ...},
#     '_dh': [
#         WindowsPath('d:/development/python/projects/jupyter_examples'),
#         WindowsPath('d:/development/python/projects/jupyter_examples')
#     ],
#     'In': [
#         '',
#         'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'inspect(__builtins__, methods=True)',
#         'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#         'locals()',
#         'vars()'
#     ],
#     'Out': {10: ...},
#     'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x04CA8850>>,
#     'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x04CA8BB0>,
#     'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x04CA8BB0>,
#     '_': ...,
#     '__': '',
#     '___': '',
#     'sys': <module 'sys' (built-in)>,
#     'os': <module 'os' from 'c:\\Users\\timsi\\AppData\\Local\\Programs\\Python\\Python310-32\\lib\\os.py'>,
#     '__vsc_ipynb_file__': 'd:\\development\\python\\projects\\jupyter_examples\\RuntimeDocumentation.ipynb',
#     '_i': 'locals()',
#     '_ii': 'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#     '_iii': 'inspect(__builtins__, methods=True)',
#     '_i1': 'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#     'inspect': <function inspect at 0x06AFE0B8>,
#     'pretty': <module 'rich.pretty' from 'c:\\Users\\timsi\\AppData\\Local\\Programs\\Python\\Python310-32\\lib\\site-packages\\rich\\pretty.py'>,
#     'print': <function print at 0x06B9CF58>,
#     'install': <function install at 0x06AFE3D0>,
#     '_i2': 'inspect(__builtins__, methods=True)',
#     '_i3': 'inspect(__builtins__, methods=True)',
#     '_i4': 'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#     '_i5': 'inspect(__builtins__, methods=True)',
#     '_i6': 'inspect(__builtins__, methods=True)',
#     '_i7': 'inspect(__builtins__, methods=True)',
#     '_i8': 'inspect(__builtins__, methods=True)',
#     '_i9': 'from rich import inspect, pretty\nfrom rich import print\nfrom rich.traceback import install\n\ninstall(show_locals=True)\npretty.install()',
#     '_i10': 'locals()',
#     '_10': ...,
#     '_i11': 'vars()'
# }
