# %%
from rich import inspect, pretty
from rich import print

pretty.install()

# %%
class Reveal:
    pass

r = Reveal()
inspect(object, methods=True, all=True)
# Out:
# ╭──────────────────────────────────── <class 'object'> ─────────────────────────────────────╮
# │ def object():                                                                             │
# │                                                                                           │
# │ The base class of the class hierarchy.                                                    │
# │                                                                                           │
# │           __doc__ = 'The base class of the class hierarchy.\n\nWhen called, it accepts no │
# │                     arguments and returns a new featureless\ninstance that has no         │
# │                     instance attributes and cannot be given any.\n'                       │
# │         __class__ = def __class__(...)                                                    │
# │                     type(object) -> the object's type                                     │
# │                     type(name, bases, dict, **kwds) -> a new type                         │
# │       __delattr__ = def __delattr__(self, name, /): Implement delattr(self, name).        │
# │           __dir__ = def __dir__(self, /): Default dir() implementation.                   │
# │            __eq__ = def __eq__(self, value, /): Return self==value.                       │
# │        __format__ = def __format__(self, format_spec, /): Default object formatter.       │
# │            __ge__ = def __ge__(self, value, /): Return self>=value.                       │
# │  __getattribute__ = def __getattribute__(self, name, /): Return getattr(self, name).      │
# │            __gt__ = def __gt__(self, value, /): Return self>value.                        │
# │          __hash__ = def __hash__(self, /): Return hash(self).                             │
# │          __init__ = def __init__(self, /, *args, **kwargs): Initialize self.  See         │
# │                     help(type(self)) for accurate signature.                              │
# │ __init_subclass__ = def __init_subclass__(...) This method is called when a class is      │
# │                     subclassed.                                                           │
# │            __le__ = def __le__(self, value, /): Return self<=value.                       │
# │            __lt__ = def __lt__(self, value, /): Return self<value.                        │
# │            __ne__ = def __ne__(self, value, /): Return self!=value.                       │
# │           __new__ = def __new__(*args, **kwargs): Create and return a new object.  See    │
# │                     help(type) for accurate signature.                                    │
# │        __reduce__ = def __reduce__(self, /): Helper for pickle.                           │
# │     __reduce_ex__ = def __reduce_ex__(self, protocol, /): Helper for pickle.              │
# │          __repr__ = def __repr__(self, /): Return repr(self).                             │
# │       __setattr__ = def __setattr__(self, name, value, /): Implement setattr(self, name,  │
# │                     value).                                                               │
# │        __sizeof__ = def __sizeof__(self, /): Size of object in memory, in bytes.          │
# │           __str__ = def __str__(self, /): Return str(self).                               │
# │  __subclasshook__ = def __subclasshook__(...) Abstract classes can override this to       │
# │                     customize issubclass().                                               │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# # Data Classes

# %% [markdown]
# ## collections.namedtuple

# %%
from collections import namedtuple

Coordinate = namedtuple('Coordinate', 'lat lon')

moscow = Coordinate(55.756, 37.617)

inspect(moscow)
moscow == Coordinate(lat=55.756, lon=37.617)  # __eq__ compares all attributes
# Out:
# ╭──── <class '__main__.Coordinate'> ─────╮
# │ Coordinate(lat, lon)                   │
# │                                        │
# │ ╭────────────────────────────────────╮ │
# │ │ Coordinate(lat=55.756, lon=37.617) │ │
# │ ╰────────────────────────────────────╯ │
# │                                        │
# │ lat = 55.756                           │
# │ lon = 37.617                           │
# ╰────────────────────────────────────────╯
# True

# %% [markdown]
# ## typing.NamedTuple

# %%
import typing

# Coordinate = typing.NamedTuple('Coordinate', [('lat', float), ('lon', float)])
# or shorter:
Coordinate = typing.NamedTuple('Coordinate', lat=float, lon=float)

moscow = Coordinate(55.756, 37.617 )# immutable instance

inspect(moscow)    
print(typing.get_type_hints(Coordinate))
# Out:
# ╭──── <class '__main__.Coordinate'> ─────╮
# │ Coordinate(lat, lon)                   │
# │                                        │
# │ ╭────────────────────────────────────╮ │
# │ │ Coordinate(lat=55.756, lon=37.617) │ │
# │ ╰────────────────────────────────────╯ │
# │                                        │
# │ lat = 55.756                           │
# │ lon = 37.617                           │
# ╰────────────────────────────────────────╯
# {'lat': <class 'float'>, 'lon': <class 'float'>}

# %%
from typing import NamedTuple

class Coordinate(NamedTuple):
    lat: float
    lon: float

moscow = Coordinate(55.756, 37.617) # immutable instance

inspect(moscow)
# Out:
# ╭──── <class '__main__.Coordinate'> ─────╮
# │ Coordinate(lat, lon)                   │
# │                                        │
# │ ╭────────────────────────────────────╮ │
# │ │ Coordinate(lat=55.756, lon=37.617) │ │
# │ ╰────────────────────────────────────╯ │
# │                                        │
# │ lat = 55.756                           │
# │ lon = 37.617                           │
# ╰────────────────────────────────────────╯

# %% [markdown]
# ## @dataclasses.dataclass

# %%
from dataclasses import dataclass
from rich.traceback import install
install(show_locals=True)
from rich import console

@dataclass(frozen=True)
class Coordinate:
    lat: float
    lon: float

moscow = Coordinate(55.756, 37.617) # mutable instance, protected with 'frozen=True'

 
inspect(moscow, dunder=True, methods=True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ C:\Users\timsi\AppData\Local\Temp\ipykernel_3580\390796426.py:14 in <module>              │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ 'C:\\Users\\timsi\\AppData\\Local\\Temp\\ipykernel_3580\\390796426.py'                    │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\site-packages\rich\__init__ │
# │ .py:168 in inspect                                                                        │
# │                                                                                           │
# │   165 │   │   all=all,                                                                    │
# │   166 │   │   value=value,                                                                │
# │   167 │   )                                                                               │
# │ ❱ 168 │   _console.print(_inspect)                                                        │
# │   169                                                                                     │
# │   170                                                                                     │
# │   171 if __name__ == "__main__":  # pragma: no cover                                      │
# │                                                                                           │
# │ ╭───────────────────────── locals ──────────────────────────╮                             │
# │ │   _console = <console width=93 ColorSystem.TRUECOLOR>     │                             │
# │ │   _inspect = <rich._inspect.Inspect object at 0x06149310> │                             │
# │ │        all = False                                        │                             │
# │ │    console = None                                         │                             │
# │ │       docs = True                                         │                             │
# │ │     dunder = True                                         │                             │
# │ │       help = False                                        │                             │
# │ │    Inspect = <class 'rich._inspect.Inspect'>              │                             │
# │ │ is_inspect = False                                        │                             │
# │ │    methods = True                                         │                             │
# │ │        obj = Coordinate(lat=55.756, lon=37.617)           │                             │
# │ │    private = False                                        │                             │
# │ │       sort = True                                         │                             │
# │ │      title = None                                         │                             │
# │ │      value = True                                         │                             │
# │ ╰───────────────────────────────────────────────────────────╯                             │
# │                                                                                           │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\site-packages\rich\console. │
# │ py:1595 in print                                                                          │
# │                                                                                           │
# │   1592 │   │   │   crop = False                                                           │
# │   1593 │   │   render_hooks = self._render_hooks[:]                                       │
# │   1594 │   │   with self:                                                                 │
# │ ❱ 1595 │   │   │   renderables = self._collect_renderables(                               │
# │   1596 │   │   │   │   objects,                                                           │
# │   1597 │   │   │   │   sep,                                                               │
# │   1598 │   │   │   │   end,                                                               │
# │                                                                                           │
# │ ╭───────────────────────────── locals ─────────────────────────────╮                      │
# │ │           crop = True                                            │                      │
# │ │          emoji = None                                            │                      │
# │ │            end = '\n'                                            │                      │
# │ │         height = None                                            │                      │
# │ │      highlight = None                                            │                      │
# │ │        justify = None                                            │                      │
# │ │         markup = None                                            │                      │
# │ │ new_line_start = False                                           │                      │
# │ │        no_wrap = None                                            │                      │
# │ │        objects = (<rich._inspect.Inspect object at 0x06149310>,) │                      │
# │ │       overflow = None                                            │                      │
# │ │   render_hooks = []                                              │                      │
# │ │           self = <console width=93 ColorSystem.TRUECOLOR>        │                      │
# │ │            sep = ' '                                             │                      │
# │ │      soft_wrap = False                                           │                      │
# │ │          style = None                                            │                      │
# │ │          width = None                                            │                      │
# │ ╰──────────────────────────────────────────────────────────────────╯                      │
# │                                                                                           │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\site-packages\rich\console. │
# │ py:1456 in _collect_renderables                                                           │
# │                                                                                           │
# │   1453 │   │   │   │   del text[:]                                                        │
# │   1454 │   │                                                                              │
# │   1455 │   │   for renderable in objects:                                                 │
# │ ❱ 1456 │   │   │   renderable = rich_cast(renderable)                                     │
# │   1457 │   │   │   if isinstance(renderable, str):                                        │
# │   1458 │   │   │   │   append_text(                                                       │
# │   1459 │   │   │   │   │   self.render_str(                                               │
# │                                                                                           │
# │ ╭─────────────────────────────────────── locals ────────────────────────────────────────╮ │
# │ │      _append = <built-in method append of list object at 0x06B01F28>                  │ │
# │ │ _highlighter = <rich.highlighter.ReprHighlighter object at 0x06D50B08>                │ │
# │ │       append = <built-in method append of list object at 0x06B01F28>                  │ │
# │ │  append_text = <built-in method append of list object at 0x06AE3A28>                  │ │
# │ │   check_text = <function Console._collect_renderables.<locals>.check_text at          │ │
# │ │                0x06D7C5C8>                                                            │ │
# │ │        emoji = None                                                                   │ │
# │ │          end = '\n'                                                                   │ │
# │ │    highlight = None                                                                   │ │
# │ │      justify = None                                                                   │ │
# │ │       markup = None                                                                   │ │
# │ │      objects = (<rich._inspect.Inspect object at 0x06149310>,)                        │ │
# │ │   renderable = <rich._inspect.Inspect object at 0x06149310>                           │ │
# │ │  renderables = []                                                                     │ │
# │ │         self = <console width=93 ColorSystem.TRUECOLOR>                               │ │
# │ │          sep = ' '                                                                    │ │
# │ │         text = []                                                                     │ │
# │ ╰───────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                           │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\site-packages\rich\protocol │
# │ .py:36 in rich_cast                                                                       │
# │                                                                                           │
# │   33 │   │   if hasattr(renderable, _GIBBERISH):                                          │
# │   34 │   │   │   return repr(renderable)                                                  │
# │   35 │   │   cast_method = getattr(renderable, "__rich__")                                │
# │ ❱ 36 │   │   renderable = cast_method()                                                   │
# │   37 │   │   renderable_type = type(renderable)                                           │
# │   38 │   │   if renderable_type in rich_visited_set:                                      │
# │   39 │   │   │   break                                                                    │
# │                                                                                           │
# │ ╭─────────────────────────────────────── locals ────────────────────────────────────────╮ │
# │ │      cast_method = <bound method Inspect.__rich__ of <rich._inspect.Inspect object at │ │
# │ │                    0x06149310>>                                                       │ │
# │ │       renderable = <rich._inspect.Inspect object at 0x06149310>                       │ │
# │ │   RenderableType = typing.Union[rich.console.ConsoleRenderable,                       │ │
# │ │                    rich.console.RichCast, str]                                        │ │
# │ │ rich_visited_set = set()                                                              │ │
# │ ╰───────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                           │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\site-packages\rich\_inspect │
# │ .py:82 in __rich__                                                                        │
# │                                                                                           │
# │    79 │                                                                                   │
# │    80 │   def __rich__(self) -> Panel:                                                    │
# │    81 │   │   return Panel.fit(                                                           │
# │ ❱  82 │   │   │   Group(*self._render()),                                                 │
# │    83 │   │   │   title=self.title,                                                       │
# │    84 │   │   │   border_style="scope.border",                                            │
# │    85 │   │   │   padding=(0, 1),                                                         │
# │                                                                                           │
# │ ╭────────────────────── locals ───────────────────────╮                                   │
# │ │ self = <rich._inspect.Inspect object at 0x06149310> │                                   │
# │ ╰─────────────────────────────────────────────────────╯                                   │
# │                                                                                           │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\site-packages\rich\_inspect │
# │ .py:187 in _render                                                                        │
# │                                                                                           │
# │   184 │   │   │   │   if not self.methods:                                                │
# │   185 │   │   │   │   │   continue                                                        │
# │   186 │   │   │   │                                                                       │
# │ ❱ 187 │   │   │   │   _signature_text = self._get_signature(key, value)                   │
# │   188 │   │   │   │   if _signature_text is None:                                         │
# │   189 │   │   │   │   │   add_row(key_text, Pretty(value, highlighter=highlighter))       │
# │   190 │   │   │   │   else:                                                               │
# │                                                                                           │
# │ ╭─────────────────────────────────────── locals ────────────────────────────────────────╮ │
# │ │            _doc = 'Coordinate(lat: float, lon: float)'                                │ │
# │ │         add_row = <bound method Table.add_row of <rich.table.Table object at          │ │
# │ │                   0x0883D8B0>>                                                        │ │
# │ │        doc_text = <text 'Coordinate(lat: float, lon: float)' [Span(10, 11,            │ │
# │ │                   'repr.brace'), Span(33, 34, 'repr.brace'), Span(0, 10,              │ │
# │ │                   'repr.call')]>                                                      │ │
# │ │           error = None                                                                │ │
# │ │     highlighter = <rich.highlighter.ReprHighlighter object at 0x06D7AD30>             │ │
# │ │           items = [                                                                   │ │
# │ │                   │   (                                                               │ │
# │ │                   │   │   '__annotations__',                                          │ │
# │ │                   │   │   (None, {'lat': <class 'float'>, 'lon': <class 'float'>})    │ │
# │ │                   │   ),                                                              │ │
# │ │                   │   (                                                               │ │
# │ │                   │   │   '__dataclass_fields__',                                     │ │
# │ │                   │   │   (                                                           │ │
# │ │                   │   │   │   None,                                                   │ │
# │ │                   │   │   │   {                                                       │ │
# │ │                   │   │   │   │   'lat': Field(name='lat',type=<class                 │ │
# │ │                   'float'>,default=<dataclasses._MISSING_TYPE object at               │ │
# │ │                   0x0388F508>,default_factory=<dataclasses._MISSING_TYPE object at    │ │
# │ │                   0x0388F508>,init=True,repr=True,hash=None,compare=True,metadata=ma… │ │
# │ │                   │   │   │   │   'lon': Field(name='lon',type=<class                 │ │
# │ │                   'float'>,default=<dataclasses._MISSING_TYPE object at               │ │
# │ │                   0x0388F508>,default_factory=<dataclasses._MISSING_TYPE object at    │ │
# │ │                   0x0388F508>,init=True,repr=True,hash=None,compare=True,metadata=ma… │ │
# │ │                   │   │   │   }                                                       │ │
# │ │                   │   │   )                                                           │ │
# │ │                   │   ),                                                              │ │
# │ │                   │   (                                                               │ │
# │ │                   │   │   '__dataclass_params__',                                     │ │
# │ │                   │   │   (                                                           │ │
# │ │                   │   │   │   None,                                                   │ │
# │ │                   │   │   │                                                           │ │
# │ │                   _DataclassParams(init=True,repr=True,eq=True,order=False,unsafe_ha… │ │
# │ │                   │   │   )                                                           │ │
# │ │                   │   ),                                                              │ │
# │ │                   │   ('__dict__', (None, {'lat': 55.756, 'lon': 37.617})),           │ │
# │ │                   │   ('__doc__', (None, 'Coordinate(lat: float, lon: float)')),      │ │
# │ │                   │   ('lat', (None, 55.756)),                                        │ │
# │ │                   │   ('lon', (None, 37.617)),                                        │ │
# │ │                   │   ('__match_args__', (None, ('lat', 'lon'))),                     │ │
# │ │                   │   ('__module__', (None, '__main__')),                             │ │
# │ │                   │   ('__weakref__', (None, None)),                                  │ │
# │ │                   │   ... +22                                                         │ │
# │ │                   ]                                                                   │ │
# │ │     items_table = <rich.table.Table object at 0x0883D8B0>                             │ │
# │ │             key = '__class__'                                                         │ │
# │ │        key_text = <text '__class__ =' [Span(0, 9, 'inspect.attr.dunder'), Span(9, 11, │ │
# │ │                   'inspect.equals')]>                                                 │ │
# │ │            keys = [                                                                   │ │
# │ │                   │   '__annotations__',                                              │ │
# │ │                   │   '__class__',                                                    │ │
# │ │                   │   '__dataclass_fields__',                                         │ │
# │ │                   │   '__dataclass_params__',                                         │ │
# │ │                   │   '__delattr__',                                                  │ │
# │ │                   │   '__dict__',                                                     │ │
# │ │                   │   '__dir__',                                                      │ │
# │ │                   │   '__doc__',                                                      │ │
# │ │                   │   '__eq__',                                                       │ │
# │ │                   │   '__format__',                                                   │ │
# │ │                   │   ... +22                                                         │ │
# │ │                   ]                                                                   │ │
# │ │ not_shown_count = 0                                                                   │ │
# │ │             obj = Coordinate(lat=55.756, lon=37.617)                                  │ │
# │ │    safe_getattr = <function Inspect._render.<locals>.safe_getattr at 0x08874100>      │ │
# │ │            self = <rich._inspect.Inspect object at 0x06149310>                        │ │
# │ │      sort_items = <function Inspect._render.<locals>.sort_items at 0x088741D8>        │ │
# │ │     total_items = 32                                                                  │ │
# │ │           value = <class '__main__.Coordinate'>                                       │ │
# │ ╰───────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                           │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\site-packages\rich\_inspect │
# │ .py:99 in _get_signature                                                                  │
# │                                                                                           │
# │    96 │   │                                                                               │
# │    97 │   │   source_filename: Optional[str] = None                                       │
# │    98 │   │   try:                                                                        │
# │ ❱  99 │   │   │   source_filename = getfile(obj)                                          │
# │   100 │   │   except TypeError:                                                           │
# │   101 │   │   │   pass                                                                    │
# │   102                                                                                     │
# │                                                                                           │
# │ ╭──────────────────────────── locals ────────────────────────────╮                        │
# │ │      _signature = '(lat: float, lon: float) -> None:'          │                        │
# │ │            name = '__class__'                                  │                        │
# │ │             obj = <class '__main__.Coordinate'>                │                        │
# │ │            self = <rich._inspect.Inspect object at 0x06149310> │                        │
# │ │ source_filename = None                                         │                        │
# │ ╰────────────────────────────────────────────────────────────────╯                        │
# │                                                                                           │
# │ c:\Users\timsi\AppData\Local\Programs\Python\Python310-32\lib\inspect.py:785 in getfile   │
# │                                                                                           │
# │    782 │   │   │   if getattr(module, '__file__', None):                                  │
# │    783 │   │   │   │   return module.__file__                                             │
# │    784 │   │   │   if object.__module__ == '__main__':                                    │
# │ ❱  785 │   │   │   │   raise OSError('source code not available')                         │
# │    786 │   │   raise TypeError('{!r} is a built-in class'.format(object))                 │
# │    787 │   if ismethod(object):                                                           │
# │    788 │   │   object = object.__func__                                                   │
# │                                                                                           │
# │ ╭──────────────── locals ────────────────╮                                                │
# │ │ module = <module '__main__'>           │                                                │
# │ │ object = <class '__main__.Coordinate'> │                                                │
# │ ╰────────────────────────────────────────╯                                                │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# OSError: source code not available
